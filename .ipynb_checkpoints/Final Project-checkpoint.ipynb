# %%
## challenge was to convert lat/long to x,y screen positions and have the nodes be at the approx relative
# positions.
## also need to ensure that East/West, North/South is translated correctly to x/y pixel coordinate system. Mostly
## trial error, but common sense, like knowing Kenmore should be to the left of South Station on network 
## and thus smaller x value helps.
## +71.05)*10000, et al is simply for giving a more granular pixel result, since ploting without this adjustment
## gives us pixels VERY close to each other

# %% [markdown]
# ### Libraries

# %%
import urllib.request, json, time
from twilio.rest import TwilioRestClient

# %% [markdown]
# ### Function Definitions

# %%
## GOOD CODE -4/26###, test again if I do TODOs

### TODO - Look at sending alerts for disabled bikes or dcoks  ###

## set a default value for map_location so we can use this for variety of texts
def send_sms_alert(message, map_location = ''):

    ## Credentials go below
    ## ACCOUNT_SID = ## Saved in environmental variables so authentication isn't hard coded in code
    ## AUTH_TOKEN = 
 
    client = TwilioRestClient() #(ACCOUNT_SID, AUTH_TOKEN) - Rest Client looks for credentials in environ variables
    client.messages.create(
        to="+18595366066", 
        from_="+16172863396",  ## this is TWILIO account phone number
        body = message + map_location)
    
        
    print('SMS message sent ', message)

##############################################################


## default msg (sent most often) will be low bikes; others added as needed
def send_alert(id, msg = 1):
    ### form the message, then call the actual function that sends it above. This function should be able to send a
    # variety of message types. After message is formed we'll pass it cleanly to the function above
    
    ## we don't need statement below but keeping as a reminder that this dict is able to be referenced whether we
    ## pass it or not as it's passed by reference not value
    global dict_bikes_master
    
    lat = dict_bikes_master[id]['lat']
    lon = dict_bikes_master[id]['lon']
    stat_name = dict_bikes_master[id]['name']
    bikes_available = dict_bikes_master[id]['num_bikes_available']
    if msg == 1:
        message_to_send = stat_name +' is low on bikes. ' + str(bikes_available) + ' available.'
        map_location = 'http://maps.apple.com/?ll='+str(lat)+','+str(lon)+'&q='+stat_name.replace(' ', '%20')
        
    ## execute Twilio message
    send_sms_alert(message_to_send, map_location)

# %%
## Standard code for opening URL and resturning JSON object
### does there need to be a 'with/open here?
def json_in(url):
    
    try:
        response = urllib.request.urlopen(url)
    except urllib.error.HTTPError as e1:
        print(e1)
    else:
        #use json.loads to unpack the json
        return json.loads(response.read().decode('utf-8'))
    

## we'll use a function for less code and cleanliness
def json_out(out_file_name, data, var_text):
    with open(out_file_name, mode = 'w') as f:
        f.write("var " + var_text + " =") #Kaleigh added this
        json.dump(data , f,indent = 2)

# %%
## GOOD CODE -4/26###

## Convert lat/long to pixels. See detailed notes
def lon_to_x(lon):
    return round((40)*(90 +(float(lon)+71.05)*10000) / 180,2)

def lat_to_y(lat):
    return round((70)*(180 -(float(lat)-42.35)*10000) / 360,2)

## shorten the name of station to first 5 words. Here for mainly cleanliness in code below        
def shorten(station):
    return' '.join(station.split( )[:5])

# %%
## TODO might need to set a return ???
def set_color_status(current_station):
    #print(current_station)
    bikes = current_station['num_bikes_available']
    current_station['color'] = 'red' if bikes < 3 else 'yellow' if bikes < 6 else 'green'

# %% [markdown]
# #### Use a print function for cell printing. This keeps our code cleaner as we are print various dictionary items and it's quite messy

# %%
def print_status_console(station):
    
    print('Time reported -',time.ctime(station['last_reported']))
    print(dict_bikes_master[station['station_id']]['name'])
    #### TODO lambda to fix singular/plural???
    print('Change of',current_bikes_avail - previous_bikes_avail, 'bikes')
    print(current_bikes_avail, '- currently available')
    print(previous_bikes_avail, '- previously available\n')

# %% [markdown]
# At time reported - Wed Apr 26 08:23:27 2017
# Burlington Ave at Brookline Ave change of
# -1 bikes
# 8 - current bikes available
# 9 - previous bikes available

# %% [markdown]
# ## Constants

# %%
## The Two Hubway Feed URLs we need
### Name, lat/long,ID
url_station_info = 'https://gbfs.thehubway.com/gbfs/en/station_information.json'

## Online?, capacity, bikes available, last rented, etc
url_station_status = 'https://gbfs.thehubway.com/gbfs/en/station_status.json'

## When to send out low bike message
alert_number = 5

## Update our feed this often in seconds. Hard coded for now from JSON feed
ttl = 10 ## TODO eventually set this from the feed data

# %% [markdown]
# ## Main Code Starts Here!
#
# ### This gets station position & name. Also our initial data for our baseline. We then update via the live feed in a
# ### loop in the following cell. This cell creates 2 JSON feeds, one with station name and position (translated from
# ### lat/lon to pixels), the second with the data we want to visualize - bikes available, total activity, bikes low?.
# ### Also save all data into a master dictionary (might do away with that).
#
# ## Split Below up into various cells as logical

# %%
## get bikes available at online stations
json_bikes_avail = json_in(url_station_status)
json_station_locations = json_in(url_station_info)

### make JSON file for status (bikes avail and color code)  and start master dictionary 
## We need two JSON files for our network visualization 1) station name/ID, position 2) station name/ID, data
dict_bikes_master = {}
json_list_bikes_avail = []
json_list_stations_locations = []


## TODO ## Possibly don't need dictionary at all, just manipulate JSON object....???

## station is open so we can plot it and update the mster dict. 220 is a test station we need to exclude
for station in json_bikes_avail['data']['stations']:    
    if station['is_renting'] == 1 and station['station_id']!= '220': 
        
#         if station['num_bikes_available'] < 3:
#             dict_bikes_master[station['station_id']] = station
#             dict_bikes_master[station['station_id']]['color'] = 'red'
#         elif station['num_bikes_available'] < 6:           
#             dict_bikes_master[station['station_id']] = station
#             dict_bikes_master[station['station_id']]['color'] = 'yellow'
#         else:
#             dict_bikes_master[station['station_id']] = station
#             dict_bikes_master[station['station_id']]['color'] = 'green'

        ## easier to get all the data as opposed to just what we need
        dict_bikes_master[station['station_id']] = station
        dict_bikes_master[station['station_id']]['total_activity'] = 0
        
        set_color_status(dict_bikes_master[station['station_id']])
            
        ## start building the bike status JSON file. Will need to add more information from 2nd feed below
        ## convert Epoch time to readable for display. Keep Epoch last updated in dictionary for comparison later
        json_list_bikes_avail.append({"ID": station['station_id'],\
                "Bikes Available": station['num_bikes_available'],\
                "Updated": time.ctime(station['last_reported']),\
                "Total Activity": dict_bikes_master[station['station_id']]['total_activity'],\
                "color": dict_bikes_master[station['station_id']]['color']})
        
        

## now finish master dict with location and name info

for station in (json_station_locations['data']['stations']):  ## 4/27 - sort in chrono order for JSON file
## so that stations are ordered correctly in viz, new on bottom in file so plotted last

# for station in sorted(json_station_locations['data']['stations'], \
#                           key=lambda k: k['last_reported'], reverse = True):

    try:
        dict_bikes_master[station['station_id']]['name'] = shorten(station['name'])
        dict_bikes_master[station['station_id']]['lat'] = station['lat'] ## TODO do we need this info in DICT?
        dict_bikes_master[station['station_id']]['lon'] = station['lon']
        ## go ahead and convert to pixels while we are fetching lat and lon
        dict_bikes_master[station['station_id']]['y'] = lat_to_y(station['lat'])
        dict_bikes_master[station['station_id']]['x'] = lon_to_x(station['lon'])       
        
        dict_bikes_master[station['station_id']]['region_id'] = station['region_id']
        
        
        ## Build our two JSON files for visualization ## TODO 4/27 - put this in a function if we are calling twice
        json_list_stations_locations.append({"name": shorten(station['name']),\
                        "Last Reported": dict_bikes_master[station['station_id']]['last_reported'],\
                        "ID": station['station_id'],\
                        "x": lon_to_x(station['lon']),\
                            "y": lat_to_y(station['lat'])})
    
    
    ## we just want to add to stations that are open, which is what our dict is. json_station_location has ALL the
    ## stations so we can use try/except to skip the ones which aren't in our master dict, ie. the closed ones
    except KeyError:
        pass


## TODO Put this in comprehension or combine with above

## Add station name to bikes available json. The feed only comes with the station ID so we must get the name
## from the station information JSON feed. The dict contains ALL info needed from both feeds so just iterate
## through it to get the names. Names are needed for display purposes.
for station in json_list_bikes_avail:
    
    station['name'] = dict_bikes_master[station['ID']]['name']
    

    ## write to our output file, sort so most current are on bottom so plotted last and thus on top
json_list_stations_locations = sorted(json_list_stations_locations, \
                                      key=lambda k: k['Last Reported'], reverse = False)    
    
json_out('project_posits.json', json_list_stations_locations, 'positions')
json_out('project_data.json', json_list_bikes_avail, 'data')

## update our point of comparison time
## we'll use this later to only look for stations that have been updated afterwards
last_compared_time = json_bikes_avail['last_updated']

# %%
json_list_stations_locations
# Out:
# [{'ID': '162',
#   'Last Reported': 1493370039,
#   'name': 'Franklin Park - Seaver St',
#   'x': -73.83,
#   'y': 113.17},
#  {'ID': '56',
#   'Last Reported': 1493370041,
#   'name': 'Dudley Square - Dudley St',
#   'x': -56.0,
#   'y': 76.51},
#  {'ID': '110',
#   'Last Reported': 1493370045,
#   'name': 'Harvard University Gund Hall at',
#   'x': -122.28,
#   'y': -16.27},
#  {'ID': '136',
#   'Last Reported': 1493370049,
#   'name': 'ID Building West',
#   'x': 60.86,
#   'y': 45.12},
#  {'ID': '195',
#   'Last Reported': 1493370049,
#   'name': 'Brian P. Murphy Staircase at',
#   'x': -28.95,
#   'y': -7.89},
#  {'ID': '17',
#   'Last Reported': 1493370055,
#   'name': 'Soldiers Field Park - 111',
#   'x': -133.85,
#   'y': 5.71},
#  {'ID': '173',
#   'Last Reported': 1493370056,
#   'name': 'Savin Hill T Stop -',
#   'x': 11.33,
#   'y': 111.61},
#  {'ID': '51',
#   'Last Reported': 1493370057,
#   'name': 'Washington St at Lenox St',
#   'x': -44.66,
#   'y': 64.41},
#  {'ID': '200',
#   'Last Reported': 1493370058,
#   'name': 'Washington St at Melnea Cass',
#   'x': -49.33,
#   'y': 68.41},
#  {'ID': '29',
#   'Last Reported': 1493370061,
#   'name': 'Innovation Lab - 125 Western',
#   'x': -145.7,
#   'y': 8.3},
#  {'ID': '138',
#   'Last Reported': 1493370068,
#   'name': 'Newmarket Square T Stop -',
#   'x': -16.66,
#   'y': 80.5},
#  {'ID': '8',
#   'Last Reported': 1493370075,
#   'name': 'Union Square - Brighton Ave',
#   'x': -174.03,
#   'y': 28.52},
#  {'ID': '201',
#   'Last Reported': 1493370085,
#   'name': 'NCAAA - Walnut Ave at',
#   'x': -73.21,
#   'y': 99.36},
#  {'ID': '97',
#   'Last Reported': 1493370086,
#   'name': 'Harvard University River Houses at',
#   'x': -129.2,
#   'y': -2.31},
#  {'ID': '45',
#   'Last Reported': 1493370088,
#   'name': 'Yawkey Way at Boylston St.',
#   'x': -85.59,
#   'y': 45.29},
#  {'ID': '194',
#   'Last Reported': 1493370091,
#   'name': 'Broadway St at Mt Pleasant',
#   'x': -42.85,
#   'y': -35.27},
#  {'ID': '84',
#   'Last Reported': 1493370092,
#   'name': 'CambridgeSide Galleria - CambridgeSide PL',
#   'x': -38.83,
#   'y': 1.98},
#  {'ID': '124',
#   'Last Reported': 1493370093,
#   'name': 'Curtis Hall - South St',
#   'x': -125.4,
#   'y': 114.62},
#  {'ID': '160',
#   'Last Reported': 1493370093,
#   'name': 'Wentworth Institute of Technology -',
#   'x': -83.09,
#   'y': 59.12},
#  {'ID': '76',
#   'Last Reported': 1493370102,
#   'name': 'Central Sq Post Office /',
#   'x': -103.32,
#   'y': 3.06},
#  {'ID': '196',
#   'Last Reported': 1493370103,
#   'name': 'Roxbury YMCA - Warren St',
#   'x': -52.56,
#   'y': 97.42},
#  {'ID': '104',
#   'Last Reported': 1493370104,
#   'name': 'Harvard University Radcliffe Quadrangle at',
#   'x': -146.9,
#   'y': -23.89},
#  {'ID': '209',
#   'Last Reported': 1493370110,
#   'name': 'Chelsea St at Saratoga St',
#   'x': 70.12,
#   'y': -22.89},
#  {'ID': '216',
#   'Last Reported': 1493370111,
#   'name': 'Glendon St at Condor St',
#   'x': 64.32,
#   'y': -28.22},
#  {'ID': '140',
#   'Last Reported': 1493370112,
#   'name': 'Danehy Park',
#   'x': -163.97,
#   'y': -40.77},
#  {'ID': '170',
#   'Last Reported': 1493370113,
#   'name': 'Franklin Park Zoo - Franklin',
#   'x': -58.55,
#   'y': 125.48},
#  {'ID': '130',
#   'Last Reported': 1493370115,
#   'name': "Upham's Corner",
#   'x': -14.14,
#   'y': 98.62},
#  {'ID': '183',
#   'Last Reported': 1493370118,
#   'name': 'Alewife MBTA at Steel Place',
#   'x': -185.79,
#   'y': -53.64},
#  {'ID': '205',
#   'Last Reported': 1493370123,
#   'name': 'Bowdoin St at Quincy St',
#   'x': -18.11,
#   'y': 119.88},
#  {'ID': '219',
#   'Last Reported': 1493370124,
#   'name': 'Central Square - East Boston',
#   'x': 45.83,
#   'y': -12.73},
#  {'ID': '77',
#   'Last Reported': 1493370130,
#   'name': 'Somerville City Hall',
#   'x': -86.93,
#   'y': -36.64},
#  {'ID': '41',
#   'Last Reported': 1493370131,
#   'name': "Packard's Corner - Commonwealth Ave",
#   'x': -144.07,
#   'y': 30.6},
#  {'ID': '204',
#   'Last Reported': 1493370131,
#   'name': 'Walnut Ave at Warren St',
#   'x': -53.86,
#   'y': 85.4},
#  {'ID': '214',
#   'Last Reported': 1493370131,
#   'name': 'Airport T Stop - Bremen',
#   'x': 61.55,
#   'y': -14.27},
#  {'ID': '215',
#   'Last Reported': 1493370134,
#   'name': 'The Eddy - New St',
#   'x': 32.89,
#   'y': -5.34},
#  {'ID': '141',
#   'Last Reported': 1493370135,
#   'name': 'Kendall Street',
#   'x': -51.48,
#   'y': 8.63},
#  {'ID': '159',
#   'Last Reported': 1493370136,
#   'name': 'S Huntington Ave at Heath',
#   'x': -115.33,
#   'y': 77.83},
#  {'ID': '112',
#   'Last Reported': 1493370138,
#   'name': 'Clarendon Hill at Broadway',
#   'x': -163.21,
#   'y': -74.48},
#  {'ID': '217',
#   'Last Reported': 1493370141,
#   'name': 'Orient Heights T Stop -',
#   'x': 117.56,
#   'y': -36.52},
#  {'ID': '50',
#   'Last Reported': 1493370145,
#   'name': 'Boylston St at Berkeley St',
#   'x': -32.54,
#   'y': 33.08},
#  {'ID': '175',
#   'Last Reported': 1493370145,
#   'name': 'Brighton Center - Washington St',
#   'x': -202.83,
#   'y': 37.04},
#  {'ID': '128',
#   'Last Reported': 1493370147,
#   'name': 'E Cottage St at Columbia',
#   'x': -6.62,
#   'y': 92.24},
#  {'ID': '171',
#   'Last Reported': 1493370147,
#   'name': 'Bunker Hill Community College',
#   'x': -22.36,
#   'y': -11.84},
#  {'ID': '199',
#   'Last Reported': 1493370150,
#   'name': "Upham's Corner T Stop -",
#   'x': -23.92,
#   'y': 95.59},
#  {'ID': '210',
#   'Last Reported': 1493370151,
#   'name': 'Bennington St at Byron St',
#   'x': 95.29,
#   'y': -29.9},
#  {'ID': '139',
#   'Last Reported': 1493370152,
#   'name': 'Dana Park',
#   'x': -109.11,
#   'y': 12.09},
#  {'ID': '12',
#   'Last Reported': 1493370154,
#   'name': 'Ruggles T Stop - Columbus',
#   'x': -65.55,
#   'y': 62.4},
#  {'ID': '180',
#   'Last Reported': 1493370157,
#   'name': 'Mt Auburn',
#   'x': -164.89,
#   'y': -13.2},
#  {'ID': '174',
#   'Last Reported': 1493370174,
#   'name': 'Washington St at Brock St',
#   'x': -225.36,
#   'y': 36.93},
#  {'ID': '212',
#   'Last Reported': 1493370174,
#   'name': 'Maverick Square - Lewis Mall',
#   'x': 41.09,
#   'y': -0.1},
#  {'ID': '52',
#   'Last Reported': 1493370177,
#   'name': 'Newbury St at Hereford St',
#   'x': -59.9,
#   'y': 37.49},
#  {'ID': '125',
#   'Last Reported': 1493370184,
#   'name': 'Hyde Square - Barbara St',
#   'x': -115.18,
#   'y': 91.39},
#  {'ID': '113',
#   'Last Reported': 1493370188,
#   'name': 'Andrew T Stop - Dorchester',
#   'x': 4.35,
#   'y': 72.5},
#  {'ID': '213',
#   'Last Reported': 1493370188,
#   'name': 'East Boston Neighborhood Health Center',
#   'x': 43.49,
#   'y': -2.99},
#  {'ID': '3',
#   'Last Reported': 1493370193,
#   'name': 'Colleges of the Fenway -',
#   'x': -92.92,
#   'y': 54.4},
#  {'ID': '46',
#   'Last Reported': 1493370198,
#   'name': 'Christian Science Plaza - Massachusetts',
#   'x': -59.82,
#   'y': 46.93},
#  {'ID': '145',
#   'Last Reported': 1493370205,
#   'name': "Rindge Avenue - O'Neill Library",
#   'x': -155.65,
#   'y': -48.16},
#  {'ID': '89',
#   'Last Reported': 1493371951,
#   'name': 'Harvard Law School at Mass',
#   'x': -135.43,
#   'y': -21.41},
#  {'ID': '142',
#   'Last Reported': 1493372579,
#   'name': 'Alewife Station at Russell Field',
#   'x': -178.8,
#   'y': -54.65},
#  {'ID': '176',
#   'Last Reported': 1493373096,
#   'name': 'Lesley University',
#   'x': -133.38,
#   'y': -36.45},
#  {'ID': '74',
#   'Last Reported': 1493373391,
#   'name': 'Harvard Square at Mass Ave/',
#   'x': -132.4,
#   'y': -10.24},
#  {'ID': '72',
#   'Last Reported': 1493373718,
#   'name': 'One Broadway / Kendall Sq',
#   'x': -55.79,
#   'y': 10.47},
#  {'ID': '90',
#   'Last Reported': 1493374554,
#   'name': 'Lechmere Station at Cambridge St',
#   'x': -38.95,
#   'y': -5.21},
#  {'ID': '93',
#   'Last Reported': 1493374728,
#   'name': 'JFK/UMass T Stop',
#   'x': 17.51,
#   'y': 92.37},
#  {'ID': '21',
#   'Last Reported': 1493375035,
#   'name': 'Prudential Center - Belvedere St',
#   'x': -52.4,
#   'y': 42.86},
#  {'ID': '167',
#   'Last Reported': 1493375398,
#   'name': 'Ryan Playground - Dorchester Ave',
#   'x': 5.19,
#   'y': 97.92},
#  {'ID': '95',
#   'Last Reported': 1493375409,
#   'name': 'Cambridge St - at Columbia',
#   'x': -78.77,
#   'y': -9.66},
#  {'ID': '118',
#   'Last Reported': 1493375457,
#   'name': 'Linear Park - Mass. Ave.',
#   'x': -158.92,
#   'y': -58.0},
#  {'ID': '33',
#   'Last Reported': 1493375497,
#   'name': 'Kenmore Square',
#   'x': -84.46,
#   'y': 37.52},
#  {'ID': '146',
#   'Last Reported': 1493375785,
#   'name': 'Murphy Skating Rink - 1880',
#   'x': 78.36,
#   'y': 61.35},
#  {'ID': '94',
#   'Last Reported': 1493376104,
#   'name': 'Main St at Austin St',
#   'x': -12.46,
#   'y': -14.78},
#  {'ID': '32',
#   'Last Reported': 1493376152,
#   'name': 'Landmark Center - Brookline Ave',
#   'x': -96.05,
#   'y': 46.84},
#  {'ID': '116',
#   'Last Reported': 1493376184,
#   'name': '359 Broadway - Broadway at',
#   'x': -100.92,
#   'y': -5.45},
#  {'ID': '99',
#   'Last Reported': 1493376336,
#   'name': 'Wilson Square',
#   'x': -120.76,
#   'y': -34.19},
#  {'ID': '98',
#   'Last Reported': 1493376540,
#   'name': 'Warren St at Chelsea St',
#   'x': -2.87,
#   'y': -7.48},
#  {'ID': '7',
#   'Last Reported': 1493376564,
#   'name': 'Fan Pier',
#   'x': 32.47,
#   'y': 28.61},
#  {'ID': '75',
#   'Last Reported': 1493376564,
#   'name': 'Lafayette Square at Mass Ave',
#   'x': -92.38,
#   'y': 8.82},
#  {'ID': '10',
#   'Last Reported': 1493376569,
#   'name': 'B.U. Central - 725 Comm.',
#   'x': -109.51,
#   'y': 34.21},
#  {'ID': '211',
#   'Last Reported': 1493376592,
#   'name': 'Piers Park',
#   'x': 53.29,
#   'y': 6.12},
#  {'ID': '108',
#   'Last Reported': 1493376677,
#   'name': 'Harvard University / SEAS Cruft-Pierce',
#   'x': -128.59,
#   'y': -19.34},
#  {'ID': '197',
#   'Last Reported': 1493376677,
#   'name': 'MLK Blvd at Washington St',
#   'x': -72.65,
#   'y': 90.29},
#  {'ID': '143',
#   'Last Reported': 1493376683,
#   'name': 'EF - North Point Park',
#   'x': -24.35,
#   'y': -3.67},
#  {'ID': '203',
#   'Last Reported': 1493376700,
#   'name': 'Columbia Rd at Ceylon St',
#   'x': -30.89,
#   'y': 113.61},
#  {'ID': '129',
#   'Last Reported': 1493376715,
#   'name': 'Hayes Square - Vine St',
#   'x': 5.32,
#   'y': -17.54},
#  {'ID': '137',
#   'Last Reported': 1493376715,
#   'name': 'Magoun Square at Trum Field',
#   'x': -108.48,
#   'y': -59.04},
#  {'ID': '122',
#   'Last Reported': 1493376731,
#   'name': 'Burlington Ave at Brookline Ave',
#   'x': -92.65,
#   'y': 43.3},
#  {'ID': '109',
#   'Last Reported': 1493376732,
#   'name': 'TD Garden - West End',
#   'x': -12.33,
#   'y': 4.0},
#  {'ID': '30',
#   'Last Reported': 1493376734,
#   'name': 'Brigham Circle - Francis St',
#   'x': -102.71,
#   'y': 65.97},
#  {'ID': '133',
#   'Last Reported': 1493376744,
#   'name': 'Green Street T Stop -',
#   'x': -107.42,
#   'y': 111.65},
#  {'ID': '63',
#   'Last Reported': 1493376765,
#   'name': 'Dorchester Ave at Gillette Park',
#   'x': 4.32,
#   'y': 46.62},
#  {'ID': '15',
#   'Last Reported': 1493376771,
#   'name': 'Brighton Mills - 370 Western',
#   'x': -175.6,
#   'y': 12.31},
#  {'ID': '23',
#   'Last Reported': 1493376815,
#   'name': 'Boston City Hall - 28',
#   'x': 3.05,
#   'y': 17.66},
#  {'ID': '65',
#   'Last Reported': 1493376821,
#   'name': 'Boston Convention and Exhibition Center',
#   'x': 33.11,
#   'y': 39.86},
#  {'ID': '14',
#   'Last Reported': 1493376842,
#   'name': 'HMS/HSPH - Avenue Louis Pasteur',
#   'x': -97.33,
#   'y': 59.95},
#  {'ID': '96',
#   'Last Reported': 1493376844,
#   'name': 'Cambridge Main Library at Broadway',
#   'x': -115.72,
#   'y': -10.46},
#  {'ID': '102',
#   'Last Reported': 1493376848,
#   'name': 'Powder House Circle - Nathan',
#   'x': -128.38,
#   'y': -63.93},
#  {'ID': '67',
#   'Last Reported': 1493376877,
#   'name': 'MIT at Mass Ave /',
#   'x': -76.0,
#   'y': 19.25},
#  {'ID': '126',
#   'Last Reported': 1493376892,
#   'name': 'Egleston Square - Atherton St',
#   'x': -88.08,
#   'y': 101.71},
#  {'ID': '152',
#   'Last Reported': 1493376898,
#   'name': 'Ink Block - Harrison Ave',
#   'x': -9.3,
#   'y': 42.97},
#  {'ID': '71',
#   'Last Reported': 1493376936,
#   'name': 'Conway Park - Somerville Avenue',
#   'x': -107.98,
#   'y': -29.95},
#  {'ID': '87',
#   'Last Reported': 1493376948,
#   'name': 'Harvard University Housing - 115',
#   'x': -122.7,
#   'y': 2.68},
#  {'ID': '202',
#   'Last Reported': 1493376955,
#   'name': 'Grove Hall Library - 41',
#   'x': -48.78,
#   'y': 116.84},
#  {'ID': '163',
#   'Last Reported': 1493376960,
#   'name': 'The Lawn on D',
#   'x': 33.28,
#   'y': 45.13},
#  {'ID': '39',
#   'Last Reported': 1493377000,
#   'name': 'Washington St at Rutland St',
#   'x': -33.42,
#   'y': 57.33},
#  {'ID': '9',
#   'Last Reported': 1493377031,
#   'name': 'Commonwealth Ave at Buick St',
#   'x': -125.86,
#   'y': 32.58},
#  {'ID': '121',
#   'Last Reported': 1493377053,
#   'name': 'W Broadway at Dorchester St',
#   'x': 29.2,
#   'y': 62.82},
#  {'ID': '78',
#   'Last Reported': 1493377125,
#   'name': 'Union Square - Somerville',
#   'x': -80.71,
#   'y': -22.63},
#  {'ID': '53',
#   'Last Reported': 1493377158,
#   'name': 'Beacon St at Massachusetts Ave',
#   'x': -68.64,
#   'y': 33.35},
#  {'ID': '81',
#   'Last Reported': 1493377186,
#   'name': 'Boylston St at Washington St',
#   'x': -8.18,
#   'y': 30.32},
#  {'ID': '37',
#   'Last Reported': 1493377245,
#   'name': 'New Balance - 20 Guest',
#   'x': -197.29,
#   'y': 20.61},
#  {'ID': '27',
#   'Last Reported': 1493377274,
#   'name': 'Roxbury Crossing T Stop -',
#   'x': -80.38,
#   'y': 71.59},
#  {'ID': '36',
#   'Last Reported': 1493377288,
#   'name': 'Copley Square - Dartmouth St',
#   'x': -40.73,
#   'y': 35.45},
#  {'ID': '61',
#   'Last Reported': 1493377313,
#   'name': 'Boylston St at Fairfield St',
#   'x': -51.96,
#   'y': 37.41},
#  {'ID': '151',
#   'Last Reported': 1493377337,
#   'name': 'Surface Rd at India St',
#   'x': 15.19,
#   'y': 19.14},
#  {'ID': '66',
#   'Last Reported': 1493377348,
#   'name': 'Allston Green District - Griggs',
#   'x': -166.69,
#   'y': 37.71},
#  {'ID': '73',
#   'Last Reported': 1493377369,
#   'name': 'Harvard Square at Brattle St',
#   'x': -137.52,
#   'y': -10.17},
#  {'ID': '149',
#   'Last Reported': 1493377376,
#   'name': '175 N Harvard St',
#   'x': -155.92,
#   'y': 8.17},
#  {'ID': '5',
#   'Last Reported': 1493377402,
#   'name': 'Northeastern University - North Parking',
#   'x': -69.29,
#   'y': 50.92},
#  {'ID': '4',
#   'Last Reported': 1493377403,
#   'name': 'Tremont St at E Berkeley',
#   'x': -23.59,
#   'y': 43.96},
#  {'ID': '161',
#   'Last Reported': 1493377465,
#   'name': 'W Broadway at D St',
#   'x': 16.79,
#   'y': 56.18},
#  {'ID': '64',
#   'Last Reported': 1493377477,
#   'name': 'Congress St at Sleeper St',
#   'x': 20.89,
#   'y': 32.86},
#  {'ID': '85',
#   'Last Reported': 1493377532,
#   'name': 'Spaulding Rehabilitation Hospital - Charlestown',
#   'x': 22.38,
#   'y': -20.1},
#  {'ID': '190',
#   'Last Reported': 1493377549,
#   'name': 'Nashua Street at Red Auerbach',
#   'x': -11.7,
#   'y': 4.52},
#  {'ID': '59',
#   'Last Reported': 1493377581,
#   'name': 'Chinatown Gate Plaza',
#   'x': -0.82,
#   'y': 32.36},
#  {'ID': '169',
#   'Last Reported': 1493377623,
#   'name': 'Edwards Playground - Main St',
#   'x': -21.35,
#   'y': -21.32},
#  {'ID': '184',
#   'Last Reported': 1493377686,
#   'name': 'Sidney Research Campus/ Erie Street',
#   'x': -99.85,
#   'y': 19.92},
#  {'ID': '177',
#   'Last Reported': 1493377712,
#   'name': 'University Park',
#   'x': -91.25,
#   'y': 10.41},
#  {'ID': '105',
#   'Last Reported': 1493377725,
#   'name': 'Lower Cambridgeport at Magazine St/Riverside',
#   'x': -121.53,
#   'y': 21.48},
#  {'ID': '55',
#   'Last Reported': 1493377754,
#   'name': 'Boylston St at Massachusetts Ave',
#   'x': -64.64,
#   'y': 40.32},
#  {'ID': '43',
#   'Last Reported': 1493377770,
#   'name': 'Rowes Wharf at Atlantic Ave',
#   'x': 18.45,
#   'y': 21.11},
#  {'ID': '6',
#   'Last Reported': 1493377793,
#   'name': 'Cambridge St at Joy St',
#   'x': -13.65,
#   'y': 13.27},
#  {'ID': '119',
#   'Last Reported': 1493377796,
#   'name': 'South Boston Library - 646',
#   'x': 44.96,
#   'y': 62.73},
#  {'ID': '26',
#   'Last Reported': 1493377811,
#   'name': 'Washington St at Waltham St',
#   'x': -22.05,
#   'y': 51.49},
#  {'ID': '135',
#   'Last Reported': 1493377819,
#   'name': 'ID Building East',
#   'x': 67.41,
#   'y': 45.06},
#  {'ID': '91',
#   'Last Reported': 1493377834,
#   'name': 'One Kendall Square at Hampshire',
#   'x': -72.64,
#   'y': 3.35},
#  {'ID': '186',
#   'Last Reported': 1493377848,
#   'name': 'Congress St at Northern Ave',
#   'x': 47.47,
#   'y': 38.69},
#  {'ID': '35',
#   'Last Reported': 1493377864,
#   'name': 'Arch St at Franklin St',
#   'x': 2.03,
#   'y': 24.5},
#  {'ID': '20',
#   'Last Reported': 1493377882,
#   'name': 'Aquarium T Stop - 200',
#   'x': 16.44,
#   'y': 16.0},
#  {'ID': '134',
#   'Last Reported': 1493377892,
#   'name': 'Boylston St at Dartmouth St',
#   'x': -39.0,
#   'y': 34.2},
#  {'ID': '49',
#   'Last Reported': 1493377910,
#   'name': 'Stuart St at Charles St',
#   'x': -16.2,
#   'y': 32.77},
#  {'ID': '185',
#   'Last Reported': 1493377914,
#   'name': 'Third at Binney',
#   'x': -52.83,
#   'y': 4.97},
#  {'ID': '24',
#   'Last Reported': 1493377952,
#   'name': 'Seaport Square - Seaport Blvd',
#   'x': 33.37,
#   'y': 32.66},
#  {'ID': '179',
#   'Last Reported': 1493377958,
#   'name': 'MIT Vassar St',
#   'x': -99.88,
#   'y': 24.11},
#  {'ID': '68',
#   'Last Reported': 1493377978,
#   'name': 'Central Square at Mass Ave',
#   'x': -98.0,
#   'y': 5.7},
#  {'ID': '192',
#   'Last Reported': 1493378010,
#   'name': 'Purchase St at Pearl St',
#   'x': 12.93,
#   'y': 25.94},
#  {'ID': '11',
#   'Last Reported': 1493378044,
#   'name': 'Longwood Ave at Binney St',
#   'x': -105.56,
#   'y': 57.11},
#  {'ID': '48',
#   'Last Reported': 1493378045,
#   'name': 'Post Office Square - Pearl',
#   'x': 7.98,
#   'y': 21.87},
#  {'ID': '115',
#   'Last Reported': 1493378056,
#   'name': 'Porter Square Station',
#   'x': -133.52,
#   'y': -38.88},
#  {'ID': '80',
#   'Last Reported': 1493378073,
#   'name': 'MIT Stata Center at Vassar',
#   'x': -73.45,
#   'y': 11.74},
#  {'ID': '22',
#   'Last Reported': 1493378147,
#   'name': 'South Station - 700 Atlantic',
#   'x': 7.67,
#   'y': 30.77},
#  {'ID': '54',
#   'Last Reported': 1493378150,
#   'name': 'Tremont St at West St',
#   'x': -9.66,
#   'y': 25.32},
#  {'ID': '25',
#   'Last Reported': 1493378167,
#   'name': 'South End Library - Tremont',
#   'x': -39.66,
#   'y': 51.85},
#  {'ID': '131',
#   'Last Reported': 1493378181,
#   'name': 'Jackson Square T Stop',
#   'x': -91.43,
#   'y': 87.63},
#  {'ID': '47',
#   'Last Reported': 1493378194,
#   'name': 'Cross St at Hanover St',
#   'x': 6.52,
#   'y': 10.09},
#  {'ID': '117',
#   'Last Reported': 1493378204,
#   'name': 'Binney St / Sixth St',
#   'x': -60.86,
#   'y': 3.7},
#  {'ID': '44',
#   'Last Reported': 1493378225,
#   'name': 'Congress St at North St',
#   'x': 3.44,
#   'y': 14.36},
#  {'ID': '150',
#   'Last Reported': 1493378243,
#   'name': 'State Street at Channel Center',
#   'x': 14.2,
#   'y': 46.4},
#  {'ID': '42',
#   'Last Reported': 1493378253,
#   'name': 'Boylston St at Arlington St',
#   'x': -25.84,
#   'y': 31.05},
#  {'ID': '79',
#   'Last Reported': 1493378255,
#   'name': 'Beacon St at Washington /',
#   'x': -103.71,
#   'y': -20.26},
#  {'ID': '19',
#   'Last Reported': 1493378257,
#   'name': 'Park Dr at Buswell St',
#   'x': -102.89,
#   'y': 40.36},
#  {'ID': '31',
#   'Last Reported': 1493378296,
#   'name': 'Seaport Hotel - Congress St',
#   'x': 38.34,
#   'y': 37.27},
#  {'ID': '107',
#   'Last Reported': 1493378312,
#   'name': 'Ames St at Main St',
#   'x': -64.93,
#   'y': 10.69},
#  {'ID': '100',
#   'Last Reported': 1493378316,
#   'name': 'Davis Square',
#   'x': -142.28,
#   'y': -56.33},
#  {'ID': '189',
#   'Last Reported': 1493378325,
#   'name': 'Kendall T',
#   'x': -57.68,
#   'y': 10.83},
#  {'ID': '88',
#   'Last Reported': 1493378330,
#   'name': 'Inman Square at Vellucci Plaza',
#   'x': -94.28,
#   'y': -11.73},
#  {'ID': '70',
#   'Last Reported': 1493378335,
#   'name': 'Harvard Kennedy School at Bennett',
#   'x': -140.6,
#   'y': -7.76},
#  {'ID': '111',
#   'Last Reported': 1493378347,
#   'name': 'Packard Ave / Powderhouse Blvd',
#   'x': -143.14,
#   'y': -70.95},
#  {'ID': '58',
#   'Last Reported': 1493378350,
#   'name': 'Beacon St at Arlington St',
#   'x': -30.62,
#   'y': 24.12},
#  {'ID': '16',
#   'Last Reported': 1493378366,
#   'name': 'Back Bay T Stop -',
#   'x': -39.04,
#   'y': 38.74},
#  {'ID': '120',
#   'Last Reported': 1493378368,
#   'name': 'Charles st and Beacon St',
#   'x': -24.11,
#   'y': 23.23},
#  {'ID': '60',
#   'Last Reported': 1493378372,
#   'name': 'Charles Circle - Charles St',
#   'x': -26.31,
#   'y': 13.93},
#  {'ID': '178',
#   'Last Reported': 1493378387,
#   'name': 'MIT Pacific St at Purrington',
#   'x': -93.99,
#   'y': 16.39},
#  {'ID': '13',
#   'Last Reported': 1493378388,
#   'name': 'Boston Medical Center - E',
#   'x': -31.31,
#   'y': 61.37}]

# %% [markdown]
# ## Update Loop Starts Here!
#
# ### So the only way to determine if a bike has been rented or returned is to compare current availability to
# ### previous availability. We have our baseline from above. Now below we will fetch all the bike availability
# ### do math, and see changes if any. Then we will update the availability and repeat....
#
# ## Split below up into various cells as able

# %% [markdown]
# ## See if we upload ALL the positions but only stations that have activity IF the colors will update...

# %%
### MAIN ###########
count = 0
json_list_bikes_avail_updated = []

## So that it doesn't run indefinitely, we will loop for ~ 2 minutes. Can run cell again without any variables
## being reset or run a few minutes later. It's just going to compare data to either the cell above 
## if this is first loop, or the last loop run here.
while count < 12:
  
    ## pause for the ttl time of the update feed. Don't want to run this right after the above cell has run
    ## so we pause at the beginning of the loop for the ttl time (set in constants). This value is hardcoded
    ## from the Hubway JSON feed and determined by Hubway. We could update less frequently if we are hitting
    ## server too often but this approximates 'real time' data 
    time.sleep(ttl)
    
    
    ## Get latest bike availability
    json_bikes_avail_updated = json_in(url_station_status)
    
    ## TODO - eventually put this in a while loop that times out after xx tries or seconds
    ## basically if the data is old sleep and try again. need a counter or something to avoid infinite loop
    
    ## feed is updated every 10 seconds and we are hitting every 10 seconds. In case we are a little early
    ## or feed is a little slow and the updated time hasn't changed, we will pause for 2 seconds and try again
    ## TODO - we will do this 30 times and then give up ### Try/Except
    while json_bikes_avail_updated['last_updated'] == last_compared_time:
        time.sleep(2)
        json_bikes_avail_updated = json_in(url_station_status)
    
    ### TODO - does this line below do anything???
    data2 = (json_bikes_avail_updated['data']['stations'])
    
    ##  display current feed time
    
    print('Current feed time is-', time.ctime(json_bikes_avail_updated['last_updated']),'\n\n')
    
#################
    ###json_list_bikes_avail_updated = [] 4/27

    #for station in json_bikes_avail_updated['data']['stations']:
        
    ## sort each update to display chronologically. Purely for display purposes
    ## this is the new JSON feed from above that we are going through chrono to see if there are changes
    ## sorting now will ensure that printing later is chronological
    
    ##http://stackoverflow.com/questions/72899/how-do-i-sort-a-list-of-dictionaries-by-values-of-the-dictionary-in-python
    for station in sorted(json_bikes_avail_updated['data']['stations'], \
                          key=lambda k: k['last_reported'], reverse = False):
    

        ## So we're looking for changes in the previous availability at stations. Instead of comparing
        ## current to previous at each station, first see if station has reported in since last update
        ## IF it hasn't then no need to do math and see if number of bikes have changed
        
    
        if (station['last_reported'] > last_compared_time):
            ## we're not going to add new stations that come online after our base case so we
            ## will exclude via try/except. Otherwise if a station comes online after we make our initial
            ## dict then we will be attempting to update a non-existent key.
            
            
            ## only need one statement in the 'try' block. If key error then use except
            ## to pass to the next if loop item, use 'else' statement to execute the rest of statements
            ## below.
            
            ## we need this assigment but are also using it as test to see if we need to ignore a new station
            try: 
                
                previous_bikes_avail = dict_bikes_master[station['station_id']]['num_bikes_available']
                
            ## key for current station in JSON feed doesn't exist in our dictionary. We will skip it
            except Exception as e:# KeyError:
                print(e)
#                 pass

            ## no exception so just finish up the loop
            else:
                
                
                ## now only deal with bikes that have changed in quantitiy, 
                ## previous is set from master dict, current is from new JSON feed
                if (previous_bikes_avail != station['num_bikes_available']):
                    current_bikes_avail = station['num_bikes_available']
                
                    ## Print functin here
                    
                    print_status_console(station)
                    

                    ## update master data
                    dict_bikes_master[station['station_id']].update(station)
                    set_color_status(dict_bikes_master[station['station_id']])
                    ## 4/25
                    ## absolute value as we are just interested in total activity
                    dict_bikes_master[station['station_id']]['total_activity'] +=\
                    abs(current_bikes_avail - previous_bikes_avail)
                    
                    ## Temp to test functionality. Will need to re-write so that all stations are written
                    ## and not just current update
                    json_list_bikes_avail_updated.append({"ID": station['station_id'],\
                        "Bikes Available": station['num_bikes_available'],\
                        "Updated": time.ctime(station['last_reported']),\
                        "Total Activity": dict_bikes_master[station['station_id']]['total_activity'],\
                        "color": dict_bikes_master[station['station_id']]['color']})




                    ########## 4/25 so is there a new JSON file yet?? Figure out today########

                    ### TODO - Figure out what to do with JSON file. Rewrite whole file and redraw? OR
                    ### write changes to new file and push that???
                    
                    ### maybe start with empty visualization and go from there
                    
                    ## start building the bike status JSON file. Will need to add more information from 2nd feed below
        ## convert Epoch time to readable for display. Keep Epoch last updated in dictionary for comparison later
#         
        
#         for station in json_list_bikes_avail:
    
#     station['name'] = dict_bikes_master[station['ID']]['name']
    


                    ## Send text message about low bikes
                    if station['num_bikes_available'] < alert_number:
                        pass
#                         send_alert(station['station_id']) ## deactivate for now 7/28
                        
                    
                    #### Added functionality here - put test for disabled bikes, etc....
                
            
## update our point of comparison time
    last_compared_time = json_bikes_avail_updated['last_updated']
    
    ### 4/27 another temporary to test functinality. will eventually pull all from dict where activity > 0
    for station in json_list_bikes_avail_updated:
    
        station['name'] = dict_bikes_master[station['ID']]['name']
        
        ## update the order of stations so newly active ones are on top
        json_list_stations_locations[station['ID']]['Last Reported'] = \
        dict_bikes_master[station['ID']]['last_reported']
        
        
        
    json_list_stations_locations = sorted(json_list_stations_locations, \
                                      key=lambda k: k['Last Reported'], reverse = False) 
    
#     ## Update position ordering - Not necessary but keeps viz ordered - 4/28
#     json_out('project_posits.json', json_list_stations_locations, 'positions')
    
    json_out('project_data.json', json_list_bikes_avail_updated, 'data')
    



    count +=1
# Out:
# Current feed time is- Fri Apr 28 08:01:28 2017
#
#
# Time reported - Fri Apr 28 07:59:19 2017
# One Broadway / Kendall Sq
# Change of 1 bikes
# 3 - currently available
# 2 - previously available
#
# SMS message sent  One Broadway / Kendall Sq is low on bikes. 3 available.
# Time reported - Fri Apr 28 07:59:21 2017
# Harvard University / SEAS Cruft-Pierce
# Change of 1 bikes
# 3 - currently available
# 2 - previously available
#
# SMS message sent  Harvard University / SEAS Cruft-Pierce is low on bikes. 3 available.
# Time reported - Fri Apr 28 07:59:26 2017
# Harvard Square at Mass Ave/
# Change of 1 bikes
# 4 - currently available
# 3 - previously available
#
# SMS message sent  Harvard Square at Mass Ave/ is low on bikes. 4 available.
# Time reported - Fri Apr 28 07:59:34 2017
# Cambridge St - at Columbia
# Change of -1 bikes
# 12 - currently available
# 13 - previously available
#
# Time reported - Fri Apr 28 07:59:36 2017
# MIT Pacific St at Purrington
# Change of -1 bikes
# 3 - currently available
# 4 - previously available
#
# SMS message sent  MIT Pacific St at Purrington is low on bikes. 3 available.
# Time reported - Fri Apr 28 07:59:37 2017
# Kendall T
# Change of -1 bikes
# 3 - currently available
# 4 - previously available
#
# SMS message sent  Kendall T is low on bikes. 3 available.
# Time reported - Fri Apr 28 07:59:46 2017
# Boston Medical Center - E
# Change of 1 bikes
# 7 - currently available
# 6 - previously available
#
# Time reported - Fri Apr 28 07:59:52 2017
# Cambridge St at Joy St
# Change of 1 bikes
# 7 - currently available
# 6 - previously available
#
# Time reported - Fri Apr 28 07:59:57 2017
# Harvard Kennedy School at Bennett
# Change of 1 bikes
# 13 - currently available
# 12 - previously available
#
# Time reported - Fri Apr 28 08:00:13 2017
# Northeastern University - North Parking
# Change of -1 bikes
# 2 - currently available
# 3 - previously available
#
# SMS message sent  Northeastern University - North Parking is low on bikes. 2 available.
# Time reported - Fri Apr 28 08:00:13 2017
# One Kendall Square at Hampshire
# Change of 1 bikes
# 18 - currently available
# 17 - previously available
#
# Time reported - Fri Apr 28 08:00:23 2017
# Rowes Wharf at Atlantic Ave
# Change of 1 bikes
# 8 - currently available
# 7 - previously available
#
# Time reported - Fri Apr 28 08:00:28 2017
# Cross St at Hanover St
# Change of -1 bikes
# 11 - currently available
# 12 - previously available
#
# Time reported - Fri Apr 28 08:00:34 2017
# Washington St at Rutland St
# Change of -1 bikes
# 12 - currently available
# 13 - previously available
#
# Time reported - Fri Apr 28 08:00:41 2017
# Christian Science Plaza - Massachusetts
# Change of -1 bikes
# 0 - currently available
# 1 - previously available
#
# SMS message sent  Christian Science Plaza - Massachusetts is low on bikes. 0 available.
# Time reported - Fri Apr 28 08:00:48 2017
# Seaport Hotel - Congress St
# Change of 1 bikes
# 2 - currently available
# 1 - previously available
#
# SMS message sent  Seaport Hotel - Congress St is low on bikes. 2 available.
# Time reported - Fri Apr 28 08:00:58 2017
# TD Garden - West End
# Change of -2 bikes
# 29 - currently available
# 31 - previously available
#
# Time reported - Fri Apr 28 08:01:03 2017
# Lechmere Station at Cambridge St
# Change of 1 bikes
# 2 - currently available
# 1 - previously available
#
# SMS message sent  Lechmere Station at Cambridge St is low on bikes. 2 available.
# Time reported - Fri Apr 28 08:01:05 2017
# Allston Green District - Griggs
# Change of -1 bikes
# 10 - currently available
# 11 - previously available
#
# Time reported - Fri Apr 28 08:01:07 2017
# Copley Square - Dartmouth St
# Change of 1 bikes
# 14 - currently available
# 13 - previously available
#
# Time reported - Fri Apr 28 08:01:07 2017
# Beacon St at Arlington St
# Change of -1 bikes
# 10 - currently available
# 11 - previously available
#
# Time reported - Fri Apr 28 08:01:19 2017
# Beacon St at Washington /
# Change of -1 bikes
# 10 - currently available
# 11 - previously available
#
# Time reported - Fri Apr 28 08:01:22 2017
# Binney St / Sixth St
# Change of 1 bikes
# 11 - currently available
# 10 - previously available
#
# Time reported - Fri Apr 28 08:01:25 2017
# Congress St at Sleeper St
# Change of -1 bikes
# 8 - currently available
# 9 - previously available
#
# Time reported - Fri Apr 28 08:01:27 2017
# Prudential Center - Belvedere St
# Change of -1 bikes
# 3 - currently available
# 4 - previously available
#
# SMS message sent  Prudential Center - Belvedere St is low on bikes. 3 available.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-c9fa123ecd7f> in <module>()
#     135
#     136         ## update the order of stations so newly active ones are on top
# --> 137         json_list_stations_locations[station['ID']]['Last Reported'] =         dict_bikes_master[station['ID']]['last_reported']
#     138
#     139
#
# TypeError: list indices must be integers or slices, not str

# %% [markdown]
# %%HTML
#
# <iframe width = "100%" height = "600" src = "good_viz.html"></iframe>

# %%
json_list_bikes_avail_updated
# Out:
# [{'Bikes Available': 3,
#   'ID': '58',
#   'Total Activity': 3,
#   'Updated': 'Thu Apr 27 08:02:16 2017',
#   'color': 'yellow'},
#  {'Bikes Available': 6,
#   'ID': '143',
#   'Total Activity': 2,
#   'Updated': 'Thu Apr 27 08:02:19 2017',
#   'color': 'green'},
#  {'Bikes Available': 12,
#   'ID': '194',
#   'Total Activity': 1,
#   'Updated': 'Thu Apr 27 08:02:21 2017',
#   'color': 'green'},
#  {'Bikes Available': 4,
#   'ID': '76',
#   'Total Activity': 2,
#   'Updated': 'Thu Apr 27 08:02:25 2017',
#   'color': 'yellow'},
#  {'Bikes Available': 7,
#   'ID': '117',
#   'Total Activity': 2,
#   'Updated': 'Thu Apr 27 08:02:30 2017',
#   'color': 'green'},
#  {'Bikes Available': 7,
#   'ID': '95',
#   'Total Activity': 1,
#   'Updated': 'Thu Apr 27 08:02:39 2017',
#   'color': 'green'},
#  {'Bikes Available': 10,
#   'ID': '81',
#   'Total Activity': 1,
#   'Updated': 'Thu Apr 27 08:02:40 2017',
#   'color': 'green'},
#  {'Bikes Available': 11,
#   'ID': '66',
#   'Total Activity': 4,
#   'Updated': 'Thu Apr 27 08:03:01 2017',
#   'color': 'green'},
#  {'Bikes Available': 6,
#   'ID': '72',
#   'Total Activity': 2,
#   'Updated': 'Thu Apr 27 08:03:09 2017',
#   'color': 'green'},
#  {'Bikes Available': 5,
#   'ID': '47',
#   'Total Activity': 2,
#   'Updated': 'Thu Apr 27 08:03:12 2017',
#   'color': 'yellow'},
#  {'Bikes Available': 14,
#   'ID': '98',
#   'Total Activity': 4,
#   'Updated': 'Thu Apr 27 08:03:13 2017',
#   'color': 'green'},
#  {'Bikes Available': 3,
#   'ID': '190',
#   'Total Activity': 5,
#   'Updated': 'Thu Apr 27 08:03:39 2017',
#   'color': 'yellow'},
#  {'Bikes Available': 9,
#   'ID': '6',
#   'Total Activity': 2,
#   'Updated': 'Thu Apr 27 08:03:47 2017',
#   'color': 'green'},
#  {'Bikes Available': 8,
#   'ID': '24',
#   'Total Activity': 2,
#   'Updated': 'Thu Apr 27 08:03:47 2017',
#   'color': 'green'},
#  {'Bikes Available': 6,
#   'ID': '179',
#   'Total Activity': 4,
#   'Updated': 'Thu Apr 27 08:03:47 2017',
#   'color': 'green'},
#  {'Bikes Available': 6,
#   'ID': '43',
#   'Total Activity': 2,
#   'Updated': 'Thu Apr 27 08:03:52 2017',
#   'color': 'green'},
#  {'Bikes Available': 5,
#   'ID': '107',
#   'Total Activity': 4,
#   'Updated': 'Thu Apr 27 08:03:55 2017',
#   'color': 'yellow'},
#  {'Bikes Available': 3,
#   'ID': '89',
#   'Total Activity': 1,
#   'Updated': 'Thu Apr 27 08:03:56 2017',
#   'color': 'yellow'},
#  {'Bikes Available': 1,
#   'ID': '189',
#   'Total Activity': 2,
#   'Updated': 'Thu Apr 27 08:03:56 2017',
#   'color': 'red'},
#  {'Bikes Available': 11,
#   'ID': '142',
#   'Total Activity': 1,
#   'Updated': 'Thu Apr 27 08:04:01 2017',
#   'color': 'green'},
#  {'Bikes Available': 16,
#   'ID': '178',
#   'Total Activity': 1,
#   'Updated': 'Thu Apr 27 08:04:02 2017',
#   'color': 'green'},
#  {'Bikes Available': 8,
#   'ID': '90',
#   'Total Activity': 2,
#   'Updated': 'Thu Apr 27 08:04:06 2017',
#   'color': 'green'},
#  {'Bikes Available': 8,
#   'ID': '122',
#   'Total Activity': 2,
#   'Updated': 'Thu Apr 27 08:04:11 2017',
#   'color': 'green'},
#  {'Bikes Available': 7,
#   'ID': '7',
#   'Total Activity': 4,
#   'Updated': 'Thu Apr 27 08:04:18 2017',
#   'color': 'green'},
#  {'Bikes Available': 7,
#   'ID': '31',
#   'Total Activity': 2,
#   'Updated': 'Thu Apr 27 08:04:26 2017',
#   'color': 'green'},
#  {'Bikes Available': 12,
#   'ID': '48',
#   'Total Activity': 3,
#   'Updated': 'Thu Apr 27 08:04:27 2017',
#   'color': 'green'},
#  {'Bikes Available': 10,
#   'ID': '39',
#   'Total Activity': 3,
#   'Updated': 'Thu Apr 27 08:04:28 2017',
#   'color': 'green'},
#  {'Bikes Available': 8,
#   'ID': '41',
#   'Total Activity': 1,
#   'Updated': 'Thu Apr 27 08:04:28 2017',
#   'color': 'green'},
#  {'Bikes Available': 13,
#   'ID': '74',
#   'Total Activity': 6,
#   'Updated': 'Thu Apr 27 08:04:31 2017',
#   'color': 'green'},
#  {'Bikes Available': 8,
#   'ID': '79',
#   'Total Activity': 4,
#   'Updated': 'Thu Apr 27 08:04:35 2017',
#   'color': 'green'},
#  {'Bikes Available': 35,
#   'ID': '22',
#   'Total Activity': 9,
#   'Updated': 'Thu Apr 27 08:05:00 2017',
#   'color': 'green'},
#  {'Bikes Available': 4,
#   'ID': '119',
#   'Total Activity': 5,
#   'Updated': 'Thu Apr 27 08:05:03 2017',
#   'color': 'yellow'},
#  {'Bikes Available': 16,
#   'ID': '13',
#   'Total Activity': 5,
#   'Updated': 'Thu Apr 27 08:05:04 2017',
#   'color': 'green'},
#  {'Bikes Available': 10,
#   'ID': '180',
#   'Total Activity': 2,
#   'Updated': 'Thu Apr 27 08:05:04 2017',
#   'color': 'green'},
#  {'Bikes Available': 7,
#   'ID': '37',
#   'Total Activity': 1,
#   'Updated': 'Thu Apr 27 08:05:19 2017',
#   'color': 'green'},
#  {'Bikes Available': 7,
#   'ID': '179',
#   'Total Activity': 5,
#   'Updated': 'Thu Apr 27 08:05:22 2017',
#   'color': 'green'},
#  {'Bikes Available': 7,
#   'ID': '23',
#   'Total Activity': 4,
#   'Updated': 'Thu Apr 27 08:05:23 2017',
#   'color': 'green'},
#  {'Bikes Available': 17,
#   'ID': '178',
#   'Total Activity': 2,
#   'Updated': 'Thu Apr 27 08:05:27 2017',
#   'color': 'green'},
#  {'Bikes Available': 8,
#   'ID': '4',
#   'Total Activity': 2,
#   'Updated': 'Thu Apr 27 08:05:31 2017',
#   'color': 'green'},
#  {'Bikes Available': 15,
#   'ID': '35',
#   'Total Activity': 7,
#   'Updated': 'Thu Apr 27 08:05:34 2017',
#   'color': 'green'},
#  {'Bikes Available': 11,
#   'ID': '48',
#   'Total Activity': 4,
#   'Updated': 'Thu Apr 27 08:05:37 2017',
#   'color': 'green'},
#  {'Bikes Available': 8,
#   'ID': '87',
#   'Total Activity': 2,
#   'Updated': 'Thu Apr 27 08:05:47 2017',
#   'color': 'green'},
#  {'Bikes Available': 2,
#   'ID': '25',
#   'Total Activity': 3,
#   'Updated': 'Thu Apr 27 08:05:49 2017',
#   'color': 'red'},
#  {'Bikes Available': 6,
#   'ID': '61',
#   'Total Activity': 1,
#   'Updated': 'Thu Apr 27 08:05:52 2017',
#   'color': 'green'},
#  {'Bikes Available': 7,
#   'ID': '43',
#   'Total Activity': 3,
#   'Updated': 'Thu Apr 27 08:06:01 2017',
#   'color': 'green'},
#  {'Bikes Available': 9,
#   'ID': '79',
#   'Total Activity': 5,
#   'Updated': 'Thu Apr 27 08:06:02 2017',
#   'color': 'green'},
#  {'Bikes Available': 1,
#   'ID': '125',
#   'Total Activity': 1,
#   'Updated': 'Thu Apr 27 08:06:02 2017',
#   'color': 'red'},
#  {'Bikes Available': 3,
#   'ID': '151',
#   'Total Activity': 6,
#   'Updated': 'Thu Apr 27 08:06:07 2017',
#   'color': 'yellow'}]

# %%
print(dict_bikes_master)
# Out:
# {'51': {'last_reported': 1493370057, 'is_renting': 1, 'y': 64.41, 'color': 'green', 'lat': 42.3348756, 'is_installed': 1, 'x': -44.66, 'total_activity': 0, 'num_bikes_disabled': 0, 'num_docks_disabled': 0, 'region_id': 10, 'station_id': '51', 'num_docks_available': 3, 'num_bikes_available': 12, 'is_returning': 1, 'name': 'Washington St at Lenox St', 'lon': -71.0790969, 'eightd_has_available_keys': False}, '189': {'last_reported': 1493379134, 'is_renting': 1, 'y': 10.83, 'color': 'yellow', 'lat': 42.362427842912396, 'is_installed': 1, 'x': -57.68, 'total_activity': 0, 'num_bikes_disabled': 0, 'num_docks_disabled': 0, 'region_id': 8, 'station_id': '189', 'num_docks_available': 18, 'num_bikes_available': 5, 'is_returning': 1, 'name': 'Kendall T', 'lon': -71.08495473861694, 'eightd_has_available_keys': False}, '178': {'last_reported': 1493378387, 'is_renting': 1, 'y': 16.39, 'color': 'yellow', 'lat': 42.35957320109044, 'is_installed': 1, 'x': -93.99, 'total_activity': 0, 'num_bikes_disabled': 0, 'num_docks_disabled': 0, 'region_id': 8, 'station_id': '178', 'num_docks_available': 14, 'num_bikes_available': 5, 'is_returning': 1, 'name': 'MIT Pacific St at Purrington', 'lon': -71.10129475593567, 'eightd_has_available_keys': False}, '105': {'last_reported': 1493377725, 'is_renting': 1, 'y': 21.48, 'color': 'green', 'lat': 42.356954, 'is_installed': 1, 'x': -121.53, 'total_activity': 0, 'num_bikes_disabled': 2, 'num_docks_disabled': 0, 'region_id': 8, 'station_id': '105', 'num_docks_available': 7, 'num_bikes_available': 10, 'is_returning': 1, 'name': 'Lower Cambridgeport at Magazine St/Riverside', 'lon': -71.113687, 'eightd_has_available_keys': False}, '97': {'last_reported': 1493370086, 'is_renting': 1, 'y': -2.31, 'color': 'green', 'lat': 42.36919031768079, 'is_installed': 1, 'x': -129.2, 'total_activity': 0, 'num_bikes_disabled': 1, 'num_docks_disabled': 0, 'region_id': 8, 'station_id': '97', 'num_docks_available': 8, 'num_bikes_available': 10, 'is_returning': 1, 'name': 'Harvard University River Houses at', 'lon': -71.11714124679565, 'eightd_has_available_keys': False}, '186': {'last_reported': 1493377848, 'is_renting': 1, 'y': 38.69, 'color': 'green', 'lat': 42.3481, 'is_installed': 1, 'x': 47.47, 'total_activity': 0, 'num_bikes_disabled': 2, 'num_docks_disabled': 0, 'region_id': 10, 'station_id': '186', 'num_docks_available': 6, 'num_bikes_available': 7, 'is_returning': 1, 'name': 'Congress St at Northern Ave', 'lon': -71.03764, 'eightd_has_available_keys': True}, '14': {'last_reported': 1493376842, 'is_renting': 1, 'y': 59.95, 'color': 'green', 'lat': 42.337171, 'is_installed': 1, 'x': -97.33, 'total_activity': 0, 'num_bikes_disabled': 2, 'num_docks_disabled': 0, 'region_id': 10, 'station_id': '14', 'num_docks_available': 6, 'num_bikes_available': 13, 'is_returning': 1, 'name': 'HMS/HSPH - Avenue Louis Pasteur', 'lon': -71.102797, 'eightd_has_available_keys': False}, '169': {'last_reported': 1493379050, 'is_renting': 1, 'y': -21.32, 'color': 'green', 'lat': 42.378965, 'is_installed': 1, 'x': -21.35, 'total_activity': 0, 'num_bikes_disabled': 1, 'num_docks_disabled': 0, 'region_id': 10, 'station_id': '169', 'num_docks_available': 3, 'num_bikes_available': 11, 'is_returning': 1, 'name': 'Edwards Playground - Main St', 'lon': -71.068607, 'eightd_has_available_keys': False}, '8': {'last_reported': 1493370075, 'is_renting': 1, 'y': 28.52, 'color': 'green', 'lat': 42.353334, 'is_installed': 1, 'x': -174.03, 'total_activity': 0, 'num_bikes_disabled': 0, 'num_docks_disabled': 0, 'region_id': 10, 'station_id': '8', 'num_docks_available': 0, 'num_bikes_available': 15, 'is_returning': 1, 'name': 'Union Square - Brighton Ave', 'lon': -71.137313, 'eightd_has_available_keys': False}, '161': {'last_reported': 1493377465, 'is_renting': 1, 'y': 56.18, 'color': 'green', 'lat': 42.3391085, 'is_installed': 1, 'x': 16.79, 'total_activity': 0, 'num_bikes_disabled': 0, 'num_docks_disabled': 0, 'region_id': 10, 'station_id': '161', 'num_docks_available ...

# %%
for station in dict_bikes_master:
    if dict_bikes_master[station]['total_activity'] > 0:
        print(dict_bikes_master[station]['total_activity'], dict_bikes_master[station]['name'])
# Out:
# 1 Ruggles T Stop - Columbus
# 1 South Boston Library - 646
# 1 MIT Stata Center at Vassar
# 1 Back Bay T Stop -
# 1 Porter Square Station

# %%
#### OLD!!! ##########


## look at test the response status for whichever lib I am using
# response = requests.get(url)

# if response.status_code == 200:

#     data = response.json()

## Basically run until program is interrupted
while True:
  
    ## pause for the ttl time of the update feed.
    time.sleep(ttl)
    
    
    json_bikes_avail_updated = json_in(url_station_status)
    
    ## TODO - eventually put this in a while loop that times out after xx tries or seconds
    ## basically if the data is old sleep and try again. need a counter or something to avoid infinite loop
    while json_bikes_avail_updated['last_updated'] == last_compared_time:
        time.sleep(2)
        json_bikes_avail_updated = json_in(url_station_status)
    
    print (type(json_bikes_avail_updated))
    #print (data)
    data2 = (json_bikes_avail_updated['data']['stations'])
#################
    json_list_bikes_avail_updated = []

    for station in json_bikes_avail_updated['data']['stations']:
        
        ## only compare stations that have been updated since last feed
        if station['last_reported'] > last_compared_time:
            ## we're not going to add new stations that come online after our base case so we
            ## will exclude via try/except.
            try:
                print(station['name'])
                print(dict_bikes_master[station['station_id']]['num_bikes_available'] - station['num_bikes_available'])
                
                
                
            except:
                pass
        
        dict_bikes_master[station['station_id']] = station ## TODO -we'll just save all the date for now, pare it down later

        if station['is_renting'] == 1 and station['station_id']!= '220': ## station is open so we can plot it and update the mster dict
            ### TODO think this is where dict is resetting. think this through....
            dict_station_locations[station['station_id']].update(station)
            if station['num_bikes_available'] < 3:
                dict_station_locations[station['station_id']]['color'] = 'red'
            elif station['num_bikes_available'] < 6:           
                dict_station_locations[station['station_id']]['color'] = 'yellow'
            else:
                dict_station_locations[station['station_id']]['color'] = 'green'


            json_list_bikes_avail.append({"ID": station['station_id'],\
                            "Bikes Available": station['num_bikes_available'],\
                            "color": dict_station_locations[station['station_id']]['color'],\
                                       "name": shorten(dict_station_locations[station['station_id']]['name'])})
        ## TODO look at reversing order dict is made so we don't have to delete items
        ## remove it from the mster dict. it was added because we had to make dict with lat/lon feed first
        ## not feed with station status
#         elif station['station_id'] != '220':
#             del dict_station_locations[station['station_id']] 

        ## write to our output file
    json_out('project_data.json', json_list_bikes_avail, 'data')
    
    
    
##################    
    ##http://stackoverflow.com/questions/72899/how-do-i-sort-a-list-of-dictionaries-by-values-of-the-dictionary-in-python
    for station in sorted(data2, key=lambda k: k['last_reported'], reverse = True):
    #for station in data2:
        if station['is_renting'] == 1 and (station['last_reported'] > last_compared_time):
            print(dict_station_locations[station['station_id']]['name'], 'Bikes available', station['num_bikes_available'], \
                  'Updated',time.ctime(station['last_reported']))
            print("Change of ",station['num_bikes_available']- \
                  dict_station_locations[station['station_id']]['num_bikes_available'],'bikes')
            
            ###TODO this doesn't appear to be working, think i"m geting cumlative frombeginning
            ## update current bikes availbe for current station
            ## master DICT is being reset somewhere. Look at Aquarium below in output
            print('debug',dict_station_locations[station['station_id']]['num_bikes_available'])
            print('debug',station['num_bikes_available'])

            dict_station_locations[station['station_id']]['num_bikes_available'] = station['num_bikes_available']
            
            print('debug',dict_station_locations[station['station_id']]['num_bikes_available'])


            
            
            if station['num_bikes_available'] < alert_number:

                ## for cleanliness in message call
                lat = dict_station_locations[station['station_id']]['lat']
                lon = dict_station_locations[station['station_id']]['lon']
                stat = dict_station_locations[station['station_id']]['name']
                send_alert()


    ## update our point of comparison time
    last_compared_time = data['last_updated']

# %% [markdown]
# http://stackoverflow.com/questions/474528/what-is-the-best-way-to-repeatedly-execute-a-function-every-x-seconds-in-python

# %% [markdown]
# ### code below is side code that eventually needs to be integrated. removes the off line statins and extends out the plotting are via changes to the pixel width in the functions

# %%
def long_to_x(long):
    return round((70)*(90 +(float(long)+71.05)*10000) / 180,2)

def lat_to_y(lat):
    return round((95)*(180 -(float(lat)-42.35)*10000) / 360,2)


json_list_stations_locations = []
for station in dict_station_locations:
    if dict_station_locations[station]['is_renting'] == 1:
  
        if dict_station_locations[station]['station_id'] != '220':
            json_list_stations_locations.append({"name": shorten(dict_station_locations[station]['name']),\
                            "ID": dict_station_locations[station]['station_id'],\
                            "x": long_to_x(dict_station_locations[station]['lon']),\
                                "y": lat_to_y(dict_station_locations[station]['lat'])})

    ## write to our output file
json_out('project_posits.json', json_list_stations_locations, 'positions')

# %%
for station in dict_station_locations:
    print(dict_station_locations[station],'\n')

# %%
for station in dict_station_locations:
    #print(dict_station_locations[station['station_id']])
    if dict_station_locations[station]['name'] == 'Davis Square':
        print(dict_station_locations[station]['num_bikes_available'])

#print(dict_station_locations['140'])
